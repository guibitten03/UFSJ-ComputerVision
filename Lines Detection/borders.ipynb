# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def detect_borders(path):
    img = plt.imread(path)
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, threshold1=50, threshold2=150)
    lines = cv2.HoughLinesP(edges, rho=1, theta=np.pi/180, threshold=100, minLineLength=100, maxLineGap=10)

    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
    plt.imshow(img)
    plt.show()

# %% [markdown]
# ## Prédios

# %%
detect_borders("predios.jpg")

# %%
detect_borders("boxes.jpg")

# %%
detect_borders("cidade.jpg")

# %%
import cv2
import numpy as np

# Load the PNG image with transparent background
image = cv2.imread('boxes.png', cv2.IMREAD_UNCHANGED)

# Create a white background image with the same dimensions as the input image
background = np.ones_like(image) * 255

# Combine the input image with the white background
result = cv2.bitwise_and(background, image)

# Save the result as a JPEG image with white background
cv2.imwrite('boxes_white_background.jpg', result)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# True
